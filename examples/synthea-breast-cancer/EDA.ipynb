# %% [markdown]
# # Exploratory Data Analysis of Synthea MCODE Breast Cancer Dataset
# This notebook gives a simple exploratory data analysis of the described Synthea dataset. The notebook assumes that you have a local instance of Katsu running on the default port with Synthea data ingested (as outlined in the federated-learning repository's README.md).
#
# No algorithm is trained over this data here, but the preprocessing techniques are similar to those used for training a model.
#
# We use pandas to perform data cleaning and heatmap creation.

# %%
import requests
import json
query = """
query{
  katsuDataModels
  {
    mcodeDataModels
    {
      mcodePackets{
        subject {
          dateOfBirth
          sex
        }
        cancerCondition {
          dateOfDiagnosis
        }
        cancerRelatedProcedures {
          code {
            label
          }
        }
        cancerDiseaseStatus {
          label
        }
        medicationStatement {
          medicationCode {
            label
          }
        }
      }
    }
  }
}
"""
url = "http://localhost:7999/graphql"
req = requests.post(url, json={'query': query})

# %%
print(req.status_code)
all_results = json.loads(req.text)['data']['katsuDataModels']['mcodeDataModels']['mcodePackets']
all_results
# Out:
# 200
# [{'subject': {'dateOfBirth': '1978-01-29', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2018-01-19T22:03:59Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Partial mastectomy (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}}],
#   'cancerDiseaseStatus': {'label': "Patient's condition improved"},
#   'medicationStatement': [{'medicationCode': {'label': 'exemestane 25 MG Oral Tablet'}}]},
#  {'subject': {'dateOfBirth': '1945-08-11', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2019-07-24T20:39:12Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Partial mastectomy (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}}],
#   'cancerDiseaseStatus': {'label': "Patient's condition improved"},
#   'medicationStatement': [{'medicationCode': {'label': '5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzumab 120 MG/ML Injection'}},
#    {'medicationCode': {'label': '5 ML fulvestrant 50 MG/ML Prefilled Syringe'}}]},
#  {'subject': {'dateOfBirth': '1966-12-15', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2018-12-02T14:18:11Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Partial mastectomy (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#    {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}}],
#   'cancerDiseaseStatus': {'label': "Patient's condition improved"},
#   'medicationStatement': [{'medicationCode': {'label': 'tamoxifen citrate 10 MG Oral Tablet'}},
#    {'medicationCode': {'label': 'palbociclib 100 MG Oral Capsule'}}]},
#  {'subject': {'dateOfBirth': '1953-11-07', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2019-10-22T08:27:51Z'}],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}},
#    {'medicationCode': {'label': '100 ML Epirubicin Hydrochloride 2 MG/ML Injection'}}]},
#  {'subject': {'dateOfBirth': '1954-03-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2017-02-24T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': '1967-05-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-02-01T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'Bevacizumab'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Irinotecan'}}]},
#  {'subject': {'dateOfBirth': '1946-04-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-07-13T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'leucovorin'}}]},
#  {'subject': {'dateOfBirth': '1965-08-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-08-31T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Bevacizumab'}},
#    {'medicationCode': {'label': 'Bevacizumab'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'Bevacizumab'}}]},
#  {'subject': {'dateOfBirth': '1971-09-01', 'sex': 'MALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-06-13T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}}]},
#  {'subject': {'dateOfBirth': '1955-09-01', 'sex': 'MALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-09-14T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}}]},
#  {'subject': {'dateOfBirth': '1951-02-01', 'sex': 'MALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2015-09-18T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}}]},
#  {'subject': {'dateOfBirth': '1979-11-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2017-02-26T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Trifluridine'}},
#    {'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}}]},
#  {'subject': {'dateOfBirth': '1968-10-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2018-12-22T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}}]},
#  {'subject': {'dateOfBirth': '1944-02-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2016-01-21T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}}]},
#  {'subject': {'dateOfBirth': '1975-05-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2018-02-07T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'leucovorin'}}]},
#  {'subject': {'dateOfBirth': '1954-12-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2019-10-31T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Bevacizumab'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Fluorouracil'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': None, 'sex': None},
#   'cancerCondition': [],
#   'cancerRelatedProcedures': [],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Unknown'}}]},
#  {'subject': {'dateOfBirth': '1961-12-01', 'sex': 'FEMALE'},
#   'cancerCondition': [{'dateOfDiagnosis': '2016-07-11T00:00:00Z'}],
#   'cancerRelatedProcedures': [{'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}},
#    {'code': {'label': 'Not available'}}],
#   'cancerDiseaseStatus': None,
#   'medicationStatement': [{'medicationCode': {'label': 'Capecitabine'}},
#    {'medicationCode': {'label': 'leucovorin'}},
#    {'medicationCode': {'label': 'Irinotecan'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}},
#    {'medicationCode': {'label': 'Bevacizumab'}},
#    {'medicationCode': {'label': 'Oxaliplatin'}}]}]

# %%
all_results[len(all_results)-25] # an arbitrary entry of our selected MCODE data.
# Out:
# {'subject': {'dateOfBirth': '1978-01-29', 'sex': 'FEMALE'},
#  'cancerCondition': [{'dateOfDiagnosis': '2018-01-19T22:03:59Z'}],
#  'cancerRelatedProcedures': [{'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Partial mastectomy (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}},
#   {'code': {'label': 'Megavoltage radiation therapy using photons (procedure)'}}],
#  'cancerDiseaseStatus': {'label': "Patient's condition improved"},
#  'medicationStatement': [{'medicationCode': {'label': 'exemestane 25 MG Oral Tablet'}}]}

# %% [markdown]
# ## Data Cleaning
# Here we drop empty columns, adjust null values, or cut rows.

# %%
import pandas as pd
df = pd.json_normalize(all_results) # converts our JSON list into a normalized pandas dataframe

# %%
for col in df:
    if df[col].astype(str).nunique() == 1:
        print(col)
        print(df[col].astype(str).unique()) # all patients are female, so we drop subject sex and null values.
        df = df.drop(col, axis=1)
# Out:
# cancerDiseaseStatus
# ['nan']

# %%
df
# Out:
#                                   cancerCondition  \
# 0   [{'dateOfDiagnosis': '2018-01-19T22:03:59Z'}]
# 1   [{'dateOfDiagnosis': '2019-07-24T20:39:12Z'}]
# 2   [{'dateOfDiagnosis': '2018-12-02T14:18:11Z'}]
# 3   [{'dateOfDiagnosis': '2019-10-22T08:27:51Z'}]
# 4   [{'dateOfDiagnosis': '2017-02-24T00:00:00Z'}]
# 5   [{'dateOfDiagnosis': '2015-02-01T00:00:00Z'}]
# 6   [{'dateOfDiagnosis': '2015-07-13T00:00:00Z'}]
# 7   [{'dateOfDiagnosis': '2015-08-31T00:00:00Z'}]
# 8   [{'dateOfDiagnosis': '2015-06-13T00:00:00Z'}]
# 9   [{'dateOfDiagnosis': '2015-09-14T00:00:00Z'}]
# 10  [{'dateOfDiagnosis': '2015-09-18T00:00:00Z'}]
# 11  [{'dateOfDiagnosis': '2017-02-26T00:00:00Z'}]
# 12  [{'dateOfDiagnosis': '2018-12-22T00:00:00Z'}]
# 13  [{'dateOfDiagnosis': '2016-01-21T00:00:00Z'}]
# 14  [{'dateOfDiagnosis': '2018-02-07T00:00:00Z'}]
# 15  [{'dateOfDiagnosis': '2019-10-31T00:00:00Z'}]
# 16                                             []
# 17                                             []
# 18                                             []
# 19                                             []
# 20                                             []
# 21                                             []
# 22                                             []
# 23                                             []
# 24  [{'dateOfDiagnosis': '2016-07-11T00:00:00Z'}]
#
#                               cancerRelatedProcedures  \
# 0   [{'code': {'label': 'Megavoltage radiation the...
# 1   [{'code': {'label': 'Megavoltage radiation the...
# 2   [{'code': {'label': 'Megavoltage radiation the...
# 3                                                  []
# 4   [{'code': {'label': 'Not available'}}, {'code'...
# 5   [{'code': {'label': 'Not available'}}, {'code'...
# 6   [{'code': {'label': 'Not available'}}, {'code'...
# 7   [{'code': {'label': 'Not available'}}, {'code'...
# 8   [{'code': {'label': 'Not available'}}, {'code'...
# 9   [{'code': {'label': 'Not available'}}, {'code'...
# 10  [{'code': {'label': 'Not available'}}, {'code'...
# 11  [{'code': {'label': 'Not available'}}, {'code'...
# 12  [{'code': {'label': 'Not available'}}, {'code'...
# 13  [{'code': {'label': 'Not available'}}, {'code'...
# 14  [{'code': {'label': 'Not available'}}, {'code'...
# 15  [{'code': {'label': 'Not available'}}, {'code'...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24  [{'code': {'label': 'Not available'}}, {'code'...
#
#                                   medicationStatement subject.dateOfBirth  \
# 0   [{'medicationCode': {'label': 'exemestane 25 M...          1978-01-29
# 1   [{'medicationCode': {'label': '5 ML hyaluronid...          1945-08-11
# 2   [{'medicationCode': {'label': 'tamoxifen citra...          1966-12-15
# 3   [{'medicationCode': {'label': '100 ML Epirubic...          1953-11-07
# 4   [{'medicationCode': {'label': 'Fluorouracil'}}...          1954-03-01
# 5   [{'medicationCode': {'label': 'Fluorouracil'}}...          1967-05-01
# 6   [{'medicationCode': {'label': 'Irinotecan'}}, ...          1946-04-01
# 7   [{'medicationCode': {'label': 'Bevacizumab'}},...          1965-08-01
# 8   [{'medicationCode': {'label': 'Oxaliplatin'}},...          1971-09-01
# 9   [{'medicationCode': {'label': 'Fluorouracil'}}...          1955-09-01
# 10  [{'medicationCode': {'label': 'leucovorin'}}, ...          1951-02-01
# 11  [{'medicationCode': {'label': 'Fluorouracil'}}...          1979-11-01
# 12  [{'medicationCode': {'label': 'Oxaliplatin'}},...          1968-10-01
# 13  [{'medicationCode': {'label': 'leucovorin'}}, ...          1944-02-01
# 14  [{'medicationCode': {'label': 'Irinotecan'}}, ...          1975-05-01
# 15  [{'medicationCode': {'label': 'Bevacizumab'}},...          1954-12-01
# 16         [{'medicationCode': {'label': 'Unknown'}}]                None
# 17         [{'medicationCode': {'label': 'Unknown'}}]                None
# 18         [{'medicationCode': {'label': 'Unknown'}}]                None
# 19         [{'medicationCode': {'label': 'Unknown'}}]                None
# 20         [{'medicationCode': {'label': 'Unknown'}}]                None
# 21         [{'medicationCode': {'label': 'Unknown'}}]                None
# 22         [{'medicationCode': {'label': 'Unknown'}}]                None
# 23         [{'medicationCode': {'label': 'Unknown'}}]                None
# 24  [{'medicationCode': {'label': 'Capecitabine'}}...          1961-12-01
#
#    subject.sex     cancerDiseaseStatus.label
# 0       FEMALE  Patient's condition improved
# 1       FEMALE  Patient's condition improved
# 2       FEMALE  Patient's condition improved
# 3       FEMALE                           NaN
# 4       FEMALE                           NaN
# 5       FEMALE                           NaN
# 6       FEMALE                           NaN
# 7       FEMALE                           NaN
# 8         MALE                           NaN
# 9         MALE                           NaN
# 10        MALE                           NaN
# 11      FEMALE                           NaN
# 12      FEMALE                           NaN
# 13      FEMALE                           NaN
# 14      FEMALE                           NaN
# 15      FEMALE                           NaN
# 16        None                           NaN
# 17        None                           NaN
# 18        None                           NaN
# 19        None                           NaN
# 20        None                           NaN
# 21        None                           NaN
# 22        None                           NaN
# 23        None                           NaN
# 24      FEMALE                           NaN

# %%
df = df.dropna(subset=['cancerDiseaseStatus.label']) # drop any rows that have empty disease status labels

# %% [markdown]
# ### Enumerate Cancer_Related_Procedures into Independent Rows

# %%
all_procs = set()
for _, row in df.iterrows():
    for i in row['cancerRelatedProcedures']:
        all_procs.add(i['code']['label'])
        
dict_list_procs = []
for _, row in df.iterrows():
    row_dict = dict.fromkeys(all_procs, 0)
    for i in row['cancerRelatedProcedures']:
        row_dict[i['code']['label']] += 1
    dict_list_procs.append(row_dict)
df_procs = pd.DataFrame(dict_list_procs)
df_procs
# Out:
#    Megavoltage radiation therapy using photons (procedure)  \
# 0                                                 34
# 1                                                 34
# 2                                                 34
#
#    Partial mastectomy (procedure)
# 0                               1
# 1                               1
# 2                               1

# %% [markdown]
# ### Enumerate Medication_Statement into Independent Rows

# %%
all_meds = set()
for _, row in df.iterrows():
    for i in row['medicationStatement']:
        all_meds.add(i['medicationCode']['label'])
        
dict_list_meds = []
for _, row in df.iterrows():
    row_dict = dict.fromkeys(all_meds, 0)
    for i in row['medicationStatement']:
        row_dict[i['medicationCode']['label']] += 1
    dict_list_meds.append(row_dict)
df_meds = pd.DataFrame(dict_list_meds)
df_meds
# Out:
#    palbociclib 100 MG Oral Capsule  \
# 0                                0
# 1                                0
# 2                                1
#
#    5 ML fulvestrant 50 MG/ML Prefilled Syringe  \
# 0                                            0
# 1                                            1
# 2                                            0
#
#    5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzumab 120 MG/ML Injection  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
#
#    exemestane 25 MG Oral Tablet  tamoxifen citrate 10 MG Oral Tablet
# 0                             1                                    0
# 1                             0                                    0
# 2                             0                                    1

# %% [markdown]
# ### Parse Diagnosis Age

# %%
import datetime
def parse_diagnosis_age(row) -> float:
    """
    A function that returns the difference (in hours) between the diagnosis date and born date of a dataframe entry.
    
    Input: A (Katsu returned) JSON object of the MCODE data.
    Output: The difference between the diagnosis date and born date.
    """
    diag_date = row['cancerCondition'][0]['dateOfDiagnosis']
    diag_age = datetime.datetime(int(diag_date[0:4]), int(diag_date[5:7]), int(diag_date[8:10]))
    born_date = row['subject.dateOfBirth']
    born_age = datetime.datetime(int(born_date[0:4]), int(born_date[5:7]), int(born_date[8:10]))
    difference = diag_age - born_age
    diff_in_hrs = divmod(difference.total_seconds(), 3600)[0] # rounded down
    return diff_in_hrs

# %%
diag_age = df.apply(lambda row: parse_diagnosis_age(row), axis=1)
diag_age_rename = diag_age.rename("diagnosisAge")
df = df.join(pd.DataFrame(diag_age_rename))

# %% [markdown]
# ### Drop Cancer Condition
# This probably wouldn't be done in a real workflow with the Synthea MCODE dataset, but I personally cannot parse what, if any of this, is relevant, so I just decided to drop the column since they all have breast cancer.
#
# I also drop the medication_statement and cancer_related_procedures since we've parsed information from them already.

# %%
df = df.drop(axis=1, labels=['cancerCondition', 'medicationStatement', 'cancerRelatedProcedures'])

# %%
dfnew = pd.concat([df.reset_index(), pd.DataFrame(dict_list_procs), pd.DataFrame(dict_list_meds)], axis=1, ignore_index=False)

# %% [markdown]
# ### One Hot Encode Cancer_Disease_Status.Label

# %%
one_hot = pd.get_dummies(dfnew['cancerDiseaseStatus.label'])
dfnew = dfnew.drop('cancerDiseaseStatus.label', axis=1)
dfnew = dfnew.join(one_hot["Patient's condition improved"])

# %% [markdown]
# ### Drop Extraneous Columns
# We drop any columns that deliver meta-information or information that is already provided by other columns.

# %%
dfnew
# Out:
#    index subject.dateOfBirth subject.sex  diagnosisAge  \
# 0      0          1978-01-29      FEMALE      350400.0
# 1      1          1945-08-11      FEMALE      648240.0
# 2      2          1966-12-15      FEMALE      455520.0
#
#    Megavoltage radiation therapy using photons (procedure)  \
# 0                                                 34
# 1                                                 34
# 2                                                 34
#
#    Partial mastectomy (procedure)  palbociclib 100 MG Oral Capsule  \
# 0                               1                                0
# 1                               1                                0
# 2                               1                                1
#
#    5 ML fulvestrant 50 MG/ML Prefilled Syringe  \
# 0                                            0
# 1                                            1
# 2                                            0
#
#    5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzumab 120 MG/ML Injection  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
#
#    exemestane 25 MG Oral Tablet  tamoxifen citrate 10 MG Oral Tablet  \
# 0                             1                                    0
# 1                             0                                    0
# 2                             0                                    1
#
#    Patient's condition improved
# 0                             1
# 1                             1
# 2                             1

# %% [markdown]
# ## Analysis/Notable Results

# %% [markdown]
# First we note that there were ~450 results with empty 'cancer_status' rows, since our dropna during cleaning left us with 1596 rows when we fetched 2052 from the dataset.
#
# Also, we note that every entry was female, and that everyone had some variant of breast cancer.
#
# Also, there are only 66 entries where the cancer worsened. The cancer_status.label column was binary, so if it did not improve, it worsened.
#
# This data-volume bias towards one of the binaries will severely impact classification models trained to try and predict this value.

# %%
len(dfnew[dfnew["Patient's condition improved"] == 0]) # how many people did not improve their cancer (worsened)
# Out:
# 0

# %% [markdown]
# ### Correlation Matrix and Heatmap
#
# We finish with a correlation matrix and heatmap. There are large correlations between different medication and cancer procedures, but there are few real correlations with whether or not a patient's condition improved. This may be because of the amount of data entries with improved results, but that means that of the 66 who worsened, there were no clear medical or procedural commonalities.

# %%
corr = dfnew.corr()
corr
# Out:
#                                                        index  diagnosisAge  \
# index                                               1.000000      0.347960
# diagnosisAge                                        0.347960      1.000000
# Megavoltage radiation therapy using photons (pr...       NaN           NaN
# Partial mastectomy (procedure)                           NaN           NaN
# palbociclib 100 MG Oral Capsule                     0.866025     -0.167412
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe         0.000000      0.937509
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...  0.000000      0.937509
# exemestane 25 MG Oral Tablet                       -0.866025     -0.770097
# tamoxifen citrate 10 MG Oral Tablet                 0.866025     -0.167412
# Patient's condition improved                             NaN           NaN
#
#                                                     Megavoltage radiation therapy using photons (procedure)  \
# index                                                                                             NaN
# diagnosisAge                                                                                      NaN
# Megavoltage radiation therapy using photons (pr...                                                NaN
# Partial mastectomy (procedure)                                                                    NaN
# palbociclib 100 MG Oral Capsule                                                                   NaN
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                                       NaN
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                                                NaN
# exemestane 25 MG Oral Tablet                                                                      NaN
# tamoxifen citrate 10 MG Oral Tablet                                                               NaN
# Patient's condition improved                                                                      NaN
#
#                                                     Partial mastectomy (procedure)  \
# index                                                                          NaN
# diagnosisAge                                                                   NaN
# Megavoltage radiation therapy using photons (pr...                             NaN
# Partial mastectomy (procedure)                                                 NaN
# palbociclib 100 MG Oral Capsule                                                NaN
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                    NaN
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                             NaN
# exemestane 25 MG Oral Tablet                                                   NaN
# tamoxifen citrate 10 MG Oral Tablet                                            NaN
# Patient's condition improved                                                   NaN
#
#                                                     palbociclib 100 MG Oral Capsule  \
# index                                                                      0.866025
# diagnosisAge                                                              -0.167412
# Megavoltage radiation therapy using photons (pr...                              NaN
# Partial mastectomy (procedure)                                                  NaN
# palbociclib 100 MG Oral Capsule                                            1.000000
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                               -0.500000
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                        -0.500000
# exemestane 25 MG Oral Tablet                                              -0.500000
# tamoxifen citrate 10 MG Oral Tablet                                        1.000000
# Patient's condition improved                                                    NaN
#
#                                                     5 ML fulvestrant 50 MG/ML Prefilled Syringe  \
# index                                                                                  0.000000
# diagnosisAge                                                                           0.937509
# Megavoltage radiation therapy using photons (pr...                                          NaN
# Partial mastectomy (procedure)                                                              NaN
# palbociclib 100 MG Oral Capsule                                                       -0.500000
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                            1.000000
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                                     1.000000
# exemestane 25 MG Oral Tablet                                                          -0.500000
# tamoxifen citrate 10 MG Oral Tablet                                                   -0.500000
# Patient's condition improved                                                                NaN
#
#                                                     5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzumab 120 MG/ML Injection  \
# index                                                                                        0.000000
# diagnosisAge                                                                                 0.937509
# Megavoltage radiation therapy using photons (pr...                                                NaN
# Partial mastectomy (procedure)                                                                    NaN
# palbociclib 100 MG Oral Capsule                                                             -0.500000
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                                  1.000000
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                                           1.000000
# exemestane 25 MG Oral Tablet                                                                -0.500000
# tamoxifen citrate 10 MG Oral Tablet                                                         -0.500000
# Patient's condition improved                                                                      NaN
#
#                                                     exemestane 25 MG Oral Tablet  \
# index                                                                  -0.866025
# diagnosisAge                                                           -0.770097
# Megavoltage radiation therapy using photons (pr...                           NaN
# Partial mastectomy (procedure)                                               NaN
# palbociclib 100 MG Oral Capsule                                        -0.500000
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                            -0.500000
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                     -0.500000
# exemestane 25 MG Oral Tablet                                            1.000000
# tamoxifen citrate 10 MG Oral Tablet                                    -0.500000
# Patient's condition improved                                                 NaN
#
#                                                     tamoxifen citrate 10 MG Oral Tablet  \
# index                                                                          0.866025
# diagnosisAge                                                                  -0.167412
# Megavoltage radiation therapy using photons (pr...                                  NaN
# Partial mastectomy (procedure)                                                      NaN
# palbociclib 100 MG Oral Capsule                                                1.000000
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                   -0.500000
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                            -0.500000
# exemestane 25 MG Oral Tablet                                                  -0.500000
# tamoxifen citrate 10 MG Oral Tablet                                            1.000000
# Patient's condition improved                                                        NaN
#
#                                                     Patient's condition improved
# index                                                                        NaN
# diagnosisAge                                                                 NaN
# Megavoltage radiation therapy using photons (pr...                           NaN
# Partial mastectomy (procedure)                                               NaN
# palbociclib 100 MG Oral Capsule                                              NaN
# 5 ML fulvestrant 50 MG/ML Prefilled Syringe                                  NaN
# 5 ML hyaluronidase-oysk 2000 UNT/ML / trastuzum...                           NaN
# exemestane 25 MG Oral Tablet                                                 NaN
# tamoxifen citrate 10 MG Oral Tablet                                          NaN
# Patient's condition improved                                                 NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/3y/0h4762vs0qxghm5xzxjc_32m0000gp/T/ipykernel_6523/2870131861.py in <module>
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
corr = dfnew.corr()
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3y/0h4762vs0qxghm5xzxjc_32m0000gp/T/ipykernel_6523/555047916.py in <module>
#       1 corr = dfnew.corr()
# ----> 2 sns.heatmap(corr)
#
# NameError: name 'sns' is not defined
